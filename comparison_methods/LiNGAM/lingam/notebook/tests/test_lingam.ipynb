# %%
# %autosave 0
# %matplotlib inline

import os, sys
sys.path.insert(0, os.path.expanduser('~/work/git/github/taku-y/lingam/python'))
# Out:
# Autosave disabled

# %% [markdown]
# # test_slttestperm

# %%
from lingam.tests.test_lingam import test_slttestperm
test_slttestperm(1)
# Out:
# Original matrix, lower triangular
# [[ 0.    0.    0.    0.    0.    0.  ]
#  [-1.03  0.    0.    0.    0.    0.  ]
#  [ 2.03  0.66  0.    0.    0.    0.  ]
#  [ 0.68 -0.94 -0.96  0.    0.    0.  ]
#  [-0.33  0.87  2.    0.01  0.    0.  ]
#  [-0.87  1.42  0.15  2.89 -0.3   0.  ]]
#
# Permutated matrix
# [[ 0.    0.    0.    0.    0.66  2.03]
#  [ 2.    0.    0.    0.01  0.87 -0.33]
#  [ 0.15 -0.3   0.    2.89  1.42 -0.87]
#  [-0.96  0.    0.    0.   -0.94  0.68]
#  [ 0.    0.    0.    0.    0.   -1.03]
#  [ 0.    0.    0.    0.    0.    0.  ]]
#
# Should be the original matrix
# [[ 0.    0.    0.    0.    0.    0.  ]
#  [-1.03  0.    0.    0.    0.    0.  ]
#  [ 2.03  0.66  0.    0.    0.    0.  ]
#  [ 0.68 -0.94 -0.96  0.    0.    0.  ]
#  [-0.33  0.87  2.    0.01  0.    0.  ]
#  [-0.87  1.42  0.15  2.89 -0.3   0.  ]]

# %% [markdown]
# # test_sltprune

# %%
from lingam.tests.test_lingam import test_sltprune
test_sltprune(10)
# Out:
# Original matrix, approximately lower triangular
# [[ 0.   -0.    0.    0.   -0.   -0.  ]
#  [-1.03 -0.    0.    0.    0.    0.  ]
#  [ 2.03  0.66 -0.   -0.    0.   -0.  ]
#  [ 0.68 -0.94 -0.95 -0.    0.   -0.  ]
#  [-0.33  0.87  2.    0.01  0.   -0.  ]
#  [-0.87  1.42  0.15  2.89 -0.31 -0.  ]]
#
# Permutated matrix
# [[ 0.   -0.    0.   -0.    0.   -0.  ]
#  [-0.33  0.    0.01 -0.    2.    0.87]
#  [ 0.68  0.   -0.   -0.   -0.95 -0.94]
#  [-0.87 -0.31  2.89 -0.    0.15  1.42]
#  [ 2.03  0.   -0.   -0.   -0.    0.66]
#  [-1.03  0.    0.    0.    0.   -0.  ]]
#
# Should be the original matrix
# [[ 0.   -0.    0.    0.   -0.   -0.  ]
#  [-1.03 -0.    0.    0.    0.    0.  ]
#  [ 2.03  0.66 -0.   -0.    0.   -0.  ]
#  [ 0.68 -0.94 -0.95 -0.    0.   -0.  ]
#  [-0.33  0.87  2.    0.01  0.   -0.  ]
#  [-0.87  1.42  0.15  2.89 -0.31 -0.  ]]
#
# Original matrix, approximately lower triangular
# [[-0.   -0.    0.   -0.    0.   -0.    0.  ]
#  [-0.65  0.    0.    0.   -0.   -0.    0.  ]
# ...

# %%
import numpy as np
b = np.arange(9).reshape(3, 3)
b.ravel()[0] = 100
print(b)
# Out:
# [[100   1   2]
#  [  3   4   5]
#  [  6   7   8]]

# %% [markdown]
# # test_gen_data_given_model

# %%
from lingam.tests.test_lingam import test_gen_data_given_model
test_gen_data_given_model(plot=True)

# %% [markdown]
# # test_ica

# %%
from lingam.tests.test_lingam import test_ica
test_ica(plot=True)

# %% [markdown]
# # test_estimate

# %%
from lingam.tests.test_lingam import test_estimate
test_estimate()
# Out:
# [[ 0.  1.  0.]
#  [ 0.  0.  0.]
#  [ 3. -2.  0.]]
# [[ 0.    1.16  0.  ]
#  [ 0.    0.    0.  ]
#  [ 3.15 -2.11  0.  ]]
