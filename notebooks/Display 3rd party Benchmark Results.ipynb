# %%
from PIL import Image

# %%
Image.open('../mooij_code/code/experiments/plots_article/ANM_all_N=Inf_FITC=100_lbfgsb_bcs_16bins_p.eps')
# Out:
# <PIL.EpsImagePlugin.EpsImageFile image mode=RGB size=471x193 at 0x7FF4CB8379E8>

# %%
Image.open('../Mooij16//code/experiments/plots_article/ANM_all_N=Inf_FITC=100_lbfgsb_bcs_8bins_p.eps')
# Out:
# <PIL.EpsImagePlugin.EpsImageFile image mode=RGB size=471x193 at 0x7FF4CB8451D0>

# %%
Image.open('../Mooij16//code/experiments/plots_article/ANM_all_N=Inf_FITC=100_lbfgsb_bcs_10samples_p.eps')
# Out:
# <PIL.EpsImagePlugin.EpsImageFile image mode=RGB size=471x193 at 0x7FF4CB845780>
