# %%
import matlab.engine
import sys
sys.path.append('..')
from benchmark_utils import get_pair

# %%
eng = matlab.engine.start_matlab()

# %%
path.ad

# %%
(x, y), true_direction = get_pair(1, 'bcs_default')

x_ = matlab.double(y.tolist())
y_ = matlab.double(x.tolist())
d = eng.vertcat(x_, y_)

# %%
eng.addpath('/afs/mpa/home/maxk/causality/comparison_methods/Mooij16/code/cep/')
# Out:
# '/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/elmat:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/strfun:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/lang:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/ops:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/iofun:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/general:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/datafun:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/matfun:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/polyfun:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/randfun:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/sparfun:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/datatypes:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/elfun:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/funfun:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/mvm:/afs/ipp/common/soft/.matlab20ff/2017b/toolbox/matlab/specfun:/afs/ipp/common/soft/.m
# ...

# %%
eng.startup(nargout=0)

# %%
eng.local_config(nargout=0)
result = eng.cep_anm(x_t, y_t, methodpars)

# %%
result['decision'] == -1
# Out:
# True

# %%
methodpars = eng.struct()
#methodpars['nrperm'] = 0
#methodpars['FITC'] =  eng.char(0
#methodpars['splitdata'] = eng.char(0)
#methodpars['evaluation'] = eng.char('pHSIC')
#methodpars['bandwidths'] = [0, 0]
#methodpars['meanf'] = eng.char('meanAffine')
#methodpars['minimize'] = eng.char('minimize_lbfgsb')
#methodpars['entest'] = eng.char('')

# %%
 if nonzero, uses this amount of points for FITC approximation (using linear grid)
    whether to split the data into a training set (for regression) and a test set (for independence testing)
     model selection criterion: 'pHSIC' (default), 'HSIC', 'entropy', 'FN', 'Gauss', or 'MML'
     bandwidths for HSIC kernel (default: [0,0])
GP pars mean function (default: 'meanAffine')
   GP pars minimization function: either 'minimize' (default) or 'minimize_lbfgsb'
 Entropy estimation method to use (see entropy.m for options)

esult           Struct that should contain the following fields:
# Out:
# {'nrperms': 100}
